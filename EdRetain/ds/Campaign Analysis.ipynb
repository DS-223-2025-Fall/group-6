# %%
#Imports 
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import text
from Database.database import engine, SessionLocal
from Database.models import (
    FactCampaignInteraction, 
    DimCampaign, 
    FactUserAnalyticsSnapshot,
    CampaignPerformance
)
print("Imports successful")
# Out:
# Imports successful

# %%
snapshot_date_key = int(datetime.now().strftime("%Y%m%d"))

print("\n" + "="*80)
print("OADING CAMPAIGN DATA")
print("="*80)

with SessionLocal() as session:
    campaigns = session.query(DimCampaign).all()
    campaigns_data = [{
        'campaign_key': c.campaign_key,
        'campaign_name': c.campaign_name,
        'target_risk_segment': c.target_risk_segment,
        'campaign_type': c.campaign_type,
        'start_date_key': c.start_date_key,
        'end_date_key': c.end_date_key
    } for c in campaigns]
    campaigns_df = pd.DataFrame(campaigns_data)
    
    interactions = session.query(FactCampaignInteraction).all()
    interactions_data = [{
        'campaign_key': i.campaign_key,
        'user_key': i.user_key,
        'sent_flag': i.sent_flag,
        'opened_flag': i.opened_flag,
        'clicked_flag': i.clicked_flag,
        'converted_flag': i.converted_flag
    } for i in interactions]
    interactions_df = pd.DataFrame(interactions_data)
    
    users = session.query(FactUserAnalyticsSnapshot).filter(
        FactUserAnalyticsSnapshot.snapshot_date_key == snapshot_date_key
    ).all()
    users_data = [{
        'user_key': u.user_key,
        'segment_label': u.segment_label,
        'engagement_level': u.engagement_level,
        'churn_probability': u.churn_probability
    } for u in users]
    users_df = pd.DataFrame(users_data)

print(f"Loaded {len(campaigns_df)} campaigns")
print(f"Loaded {len(interactions_df):,} interactions")
print(f"Loaded {len(users_df):,} users")

print("\nCampaigns to Analyze:")
print(campaigns_df[['campaign_name', 'target_risk_segment', 'start_date_key']].to_string(index=False))
# Out:
# ================================================================================
# OADING CAMPAIGN DATA
# ================================================================================
# Loaded 50 campaigns
# Loaded 2,000 interactions
# Loaded 1,000 users
#
# Campaigns to Analyze:
#                 campaign_name target_risk_segment  start_date_key
#      Onboarding Campaign Mind           All Users        20251116
#   Onboarding Campaign Compare           All Users        20250901
#       Onboarding Campaign Cut           All Users        20250914
#  Onboarding Campaign Cultural           All Users        20250927
#        Upsell Campaign Minute         Medium Risk        20250903
#     Upsell Campaign President         Medium Risk        20250910
#         Upsell Campaign Owner         Medium Risk        20251126
#     Retention Campaign Nature           High Risk        20250831
#         Upsell Campaign Offer              Active        20250929
#        Retention Campaign For           High Risk        20251115
#    Onboarding Campaign Sister           All Users        20251112
#    Retention Campaign Science           High Risk        20250929
#         Upsell Campaign Place         Medium Risk        20251121
#        Upsell Campaign Speech              Active        20251106
#     Upsell Campaign Challenge         Medium Risk        20251027
#        Upsell Campaign Return         Medium Risk        20251003
#   Reactivation Campaign Often             Churned        20250912
#     Reactivation Campaign Day            Inactive        20251031
#    Onboarding Campaign Member           New Users        20250913
# Retention Campaign Successful           High Risk        20250902
#     Retention Campaign Travel           High Risk        20250918
#    Retention Campaign Instead           High Risk        20250912
#       Upsell Campaign Million              Active        20251029
#     Retention Campaign Moment             At Risk        20250908
# Reactivation Campaign Require            Inactive        20250926
#     Reactivation Campaign But            Inactive        20251118
#         Upsell Campaign World              Active        20251003
#     Onboarding Campaign Shake           New Users        20250929
#        Retention Campaign Six           High Risk        20251002
# Reactivation Campaign Discuss            Inactive        20251023
#        Upsell Campaign Center         Medium Risk        20251116
#    Onboarding Campaign Attack           All Users        20250929
#     Reactivation Campaign Why            Inactive        20250907
# Reactivation Campaign Support             Churned        20251019
#       Retention Campaign Data             At Risk        20250930
#       Retention Campaign Onto           High Risk        20251026
#       Onboarding Campaign Lot           New Users        20250930
#       Onboarding Campaign Job           New Users        20251005
#  Reactivation Campaign Though            Inactive        20250925
#   Onboarding Campaign Compare           New Users        20250830
#       Retention Campaign Sell           High Risk        20250831
#      Onboarding Campaign Word           New Users        20251125
#       Retention Campaign Unit           High Risk        20251112
#       Upsell Campaign Subject              Active        20251111
#     Onboarding Campaign Admit           New Users        20250923
#    Onboarding Campaign Threat           New Users        20251123
#    Reactivation Campaign Hard             Churned        20250906
#     Reactivation Campaign Off             Churned        20250924
# Reactivation Campaign Mission             Churned        20251017
#      Retention Campaign Dream           High Risk        20250917

# %%
print("\n" + "="*80)
print("CALCULATING PER-CAMPAIGN PERFORMANCE")
print("="*80)

campaign_performance_list = []

for idx, campaign in campaigns_df.iterrows():
    campaign_key = campaign['campaign_key']
    campaign_name = campaign['campaign_name']
    target_segment = campaign['target_risk_segment']
    
    print(f"\n{'='*60}")
    print(f"Campaign: {campaign_name}")
    print(f"   Target: {target_segment}")
    print(f"{'='*60}")
    
    campaign_interactions = interactions_df[interactions_df['campaign_key'] == campaign_key]
    
    if len(campaign_interactions) == 0:
        print(f"No interactions found - skipping")
        continue
    
    # Open rate
    users_sent = int(campaign_interactions['sent_flag'].sum())
    users_opened = int(campaign_interactions['opened_flag'].sum())
    open_rate = (users_opened / users_sent * 100) if users_sent > 0 else 0
    
    print(f"   📧 Open Rate: {open_rate:.1f}% ({users_opened}/{users_sent})")
    
    # Retention lift
    campaign_user_keys = campaign_interactions['user_key'].unique()
    campaign_users = users_df[users_df['user_key'].isin(campaign_user_keys)].copy()
    
    segment_mapping = {
        'At-Risk': ['At-Risk Premium', 'Declining Premium', 'Need Attention'],
        'Dormant': ['Dormant Premium', 'Recently Churned'],
        'Medium': ['Medium Engaged', 'Potential Loyalists'],
        'Highly Engaged': ['Champions', 'Loyal Customers', 'Highly Engaged'],
        'All': None  
    }
    
    if target_segment and target_segment in segment_mapping:
        target_segments = segment_mapping[target_segment]
        
        if target_segments:
            # Control: same segment type, didn't receive campaign
            control_users = users_df[
                (~users_df['user_key'].isin(campaign_user_keys)) &
                (users_df['segment_label'].isin(target_segments))
            ].copy()
        else:
            # Target = All
            control_users = users_df[~users_df['user_key'].isin(campaign_user_keys)].copy()
    else:
        control_users = users_df[~users_df['user_key'].isin(campaign_user_keys)].copy()
    
    print(f"Campaign Group: {len(campaign_users):,} users")
    print(f"Control Group:  {len(control_users):,} users")
    
    if len(control_users) == 0:
        print(f"WARNING: No control users found for segment '{target_segment}'")
        print(f"Using all non-campaign users as control")
        control_users = users_df[~users_df['user_key'].isin(campaign_user_keys)].copy()
        print(f"Control Group (fallback): {len(control_users):,} users")
    
    campaign_users['is_retained'] = (
        ~campaign_users['segment_label'].isin(['Recently Churned', 'Dormant Premium']) &
        (campaign_users['churn_probability'] < 0.5)
    ).astype(int)
    
    control_users['is_retained'] = (
        ~control_users['segment_label'].isin(['Recently Churned', 'Dormant Premium']) &
        (control_users['churn_probability'] < 0.5)
    ).astype(int)
    
    campaign_retention = (campaign_users['is_retained'].mean() * 100) if len(campaign_users) > 0 else 0
    control_retention = (control_users['is_retained'].mean() * 100) if len(control_users) > 0 else 0
    retention_lift = campaign_retention - control_retention
    
    print(f"Campaign Retention: {campaign_retention:.1f}%")
    print(f"Control Retention:  {control_retention:.1f}%")
    print(f"Retention Lift:     {retention_lift:+.1f}%")
    
    # Churn Rate
    campaign_churn_rate = 100 - campaign_retention
    control_churn_rate = 100 - control_retention
    
    print(f"Campaign Churn Rate: {campaign_churn_rate:.1f}%")
    print(f"Control Churn Rate:  {control_churn_rate:.1f}%")
    
    # Status
    current_date = int(datetime.now().strftime("%Y%m%d"))
    
    if campaign['end_date_key'] and current_date > campaign['end_date_key']:
        status = "Completed"
    elif campaign['start_date_key'] and current_date >= campaign['start_date_key']:
        status = "Active"
    else:
        status = "Scheduled"
    
    print(f"Status: {status}")
    
    # Results
    campaign_performance_list.append({
        'campaign_key': campaign_key,
        'snapshot_date_key': snapshot_date_key,
        'campaign_name': campaign_name,
        'target_segment': target_segment,
        'launch_date': campaign['start_date_key'],
        'users_sent': users_sent,
        'users_opened': users_opened,
        'open_rate': round(open_rate, 1),
        'campaign_retention_rate': round(campaign_retention, 1),
        'control_retention_rate': round(control_retention, 1),
        'retention_lift': round(retention_lift, 1),
        'campaign_churn_rate': round(campaign_churn_rate, 1),      # ← NEW
        'control_churn_rate': round(control_churn_rate, 1),        # ← NEW
        'campaign_size': len(campaign_users),
        'control_size': len(control_users),
        'status': status,
        'created_at': datetime.now()
    })

campaign_performance_df = pd.DataFrame(campaign_performance_list)

print("\n" + "="*80)
print("CAMPAIGN PERFORMANCE SUMMARY")
print("="*80)
print(campaign_performance_df[[
    'campaign_name', 
    'target_segment',
    'open_rate', 
    'retention_lift',
    'status'
]].to_string(index=False))
# Out:
# ================================================================================
# CALCULATING PER-CAMPAIGN PERFORMANCE
# ================================================================================
#
# ============================================================
# Campaign: Onboarding Campaign Mind
#    Target: All Users
# ============================================================
#    📧 Open Rate: 74.4% (32/43)
# Campaign Group: 42 users
# Control Group:  958 users
# Campaign Retention: 50.0%
# Control Retention:  45.6%
# Retention Lift:     +4.4%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Compare
#    Target: All Users
# ============================================================
#    📧 Open Rate: 72.7% (24/33)
# Campaign Group: 33 users
# Control Group:  967 users
# Campaign Retention: 48.5%
# Control Retention:  45.7%
# Retention Lift:     +2.8%
# Campaign Churn Rate: 51.5%
# Control Churn Rate:  54.3%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Cut
#    Target: All Users
# ============================================================
#    📧 Open Rate: 75.0% (27/36)
# Campaign Group: 35 users
# Control Group:  965 users
# Campaign Retention: 48.6%
# Control Retention:  45.7%
# Retention Lift:     +2.9%
# Campaign Churn Rate: 51.4%
# Control Churn Rate:  54.3%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Cultural
#    Target: All Users
# ============================================================
#    📧 Open Rate: 78.3% (36/46)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 45.5%
# Control Retention:  45.8%
# Retention Lift:     -0.4%
# Campaign Churn Rate: 54.5%
# Control Churn Rate:  54.2%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Minute
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 90.9% (40/44)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 56.8%
# Control Retention:  45.3%
# Retention Lift:     +11.5%
# Campaign Churn Rate: 43.2%
# Control Churn Rate:  54.7%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign President
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 82.0% (41/50)
# Campaign Group: 47 users
# Control Group:  953 users
# Campaign Retention: 44.7%
# Control Retention:  45.9%
# Retention Lift:     -1.2%
# Campaign Churn Rate: 55.3%
# Control Churn Rate:  54.1%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Owner
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 76.2% (32/42)
# Campaign Group: 41 users
# Control Group:  959 users
# Campaign Retention: 43.9%
# Control Retention:  45.9%
# Retention Lift:     -2.0%
# Campaign Churn Rate: 56.1%
# Control Churn Rate:  54.1%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Nature
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 84.4% (27/32)
# Campaign Group: 32 users
# Control Group:  968 users
# Campaign Retention: 56.2%
# Control Retention:  45.5%
# Retention Lift:     +10.8%
# Campaign Churn Rate: 43.8%
# Control Churn Rate:  54.5%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Offer
#    Target: Active
# ============================================================
#    📧 Open Rate: 85.7% (36/42)
# Campaign Group: 40 users
# Control Group:  960 users
# Campaign Retention: 32.5%
# Control Retention:  46.4%
# Retention Lift:     -13.9%
# Campaign Churn Rate: 67.5%
# Control Churn Rate:  53.6%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign For
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 79.5% (35/44)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 50.0%
# Control Retention:  45.6%
# Retention Lift:     +4.4%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Sister
#    Target: All Users
# ============================================================
#    📧 Open Rate: 87.8% (36/41)
# Campaign Group: 41 users
# Control Group:  959 users
# Campaign Retention: 56.1%
# Control Retention:  45.4%
# Retention Lift:     +10.7%
# Campaign Churn Rate: 43.9%
# Control Churn Rate:  54.6%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Science
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 73.0% (27/37)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 52.8%
# Control Retention:  45.5%
# Retention Lift:     +7.2%
# Campaign Churn Rate: 47.2%
# Control Churn Rate:  54.5%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Place
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 77.1% (37/48)
# Campaign Group: 48 users
# Control Group:  952 users
# Campaign Retention: 45.8%
# Control Retention:  45.8%
# Retention Lift:     +0.0%
# Campaign Churn Rate: 54.2%
# Control Churn Rate:  54.2%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Speech
#    Target: Active
# ============================================================
#    📧 Open Rate: 87.2% (41/47)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 40.9%
# Control Retention:  46.0%
# Retention Lift:     -5.1%
# Campaign Churn Rate: 59.1%
# Control Churn Rate:  54.0%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Challenge
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 81.2% (26/32)
# Campaign Group: 31 users
# Control Group:  969 users
# Campaign Retention: 54.8%
# Control Retention:  45.5%
# Retention Lift:     +9.3%
# Campaign Churn Rate: 45.2%
# Control Churn Rate:  54.5%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Return
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 69.2% (27/39)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 43.6%
# Control Retention:  45.9%
# Retention Lift:     -2.3%
# Campaign Churn Rate: 56.4%
# Control Churn Rate:  54.1%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Often
#    Target: Churned
# ============================================================
#    📧 Open Rate: 76.5% (26/34)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 58.8%
# Control Retention:  45.3%
# Retention Lift:     +13.5%
# Campaign Churn Rate: 41.2%
# Control Churn Rate:  54.7%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Day
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 97.1% (34/35)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 47.1%
# Control Retention:  45.8%
# Retention Lift:     +1.3%
# Campaign Churn Rate: 52.9%
# Control Churn Rate:  54.2%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Member
#    Target: New Users
# ============================================================
#    📧 Open Rate: 74.4% (29/39)
# Campaign Group: 38 users
# Control Group:  962 users
# Campaign Retention: 26.3%
# Control Retention:  46.6%
# Retention Lift:     -20.3%
# Campaign Churn Rate: 73.7%
# Control Churn Rate:  53.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Successful
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 76.3% (29/38)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 51.4%
# Control Retention:  45.6%
# Retention Lift:     +5.8%
# Campaign Churn Rate: 48.6%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Travel
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 75.0% (36/48)
# Campaign Group: 47 users
# Control Group:  953 users
# Campaign Retention: 46.8%
# Control Retention:  45.8%
# Retention Lift:     +1.1%
# Campaign Churn Rate: 53.2%
# Control Churn Rate:  54.2%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Instead
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 80.0% (36/45)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 50.0%
# Control Retention:  45.6%
# Retention Lift:     +4.4%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Million
#    Target: Active
# ============================================================
#    📧 Open Rate: 84.4% (27/32)
# Campaign Group: 32 users
# Control Group:  968 users
# Campaign Retention: 53.1%
# Control Retention:  45.6%
# Retention Lift:     +7.6%
# Campaign Churn Rate: 46.9%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Moment
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 82.6% (38/46)
# Campaign Group: 46 users
# Control Group:  954 users
# Campaign Retention: 58.7%
# Control Retention:  45.2%
# Retention Lift:     +13.5%
# Campaign Churn Rate: 41.3%
# Control Churn Rate:  54.8%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Require
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 73.5% (25/34)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 38.2%
# Control Retention:  46.1%
# Retention Lift:     -7.8%
# Campaign Churn Rate: 61.8%
# Control Churn Rate:  53.9%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign But
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 85.0% (34/40)
# Campaign Group: 40 users
# Control Group:  960 users
# Campaign Retention: 40.0%
# Control Retention:  46.0%
# Retention Lift:     -6.0%
# Campaign Churn Rate: 60.0%
# Control Churn Rate:  54.0%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign World
#    Target: Active
# ============================================================
#    📧 Open Rate: 75.5% (37/49)
# Campaign Group: 49 users
# Control Group:  951 users
# Campaign Retention: 46.9%
# Control Retention:  45.7%
# Retention Lift:     +1.2%
# Campaign Churn Rate: 53.1%
# Control Churn Rate:  54.3%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Shake
#    Target: New Users
# ============================================================
#    📧 Open Rate: 82.2% (37/45)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 27.3%
# Control Retention:  46.7%
# Retention Lift:     -19.4%
# Campaign Churn Rate: 72.7%
# Control Churn Rate:  53.3%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Six
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 72.2% (26/36)
# Campaign Group: 35 users
# Control Group:  965 users
# Campaign Retention: 51.4%
# Control Retention:  45.6%
# Retention Lift:     +5.8%
# Campaign Churn Rate: 48.6%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Discuss
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 83.7% (36/43)
# Campaign Group: 41 users
# Control Group:  959 users
# Campaign Retention: 48.8%
# Control Retention:  45.7%
# Retention Lift:     +3.1%
# Campaign Churn Rate: 51.2%
# Control Churn Rate:  54.3%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Center
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 78.1% (25/32)
# Campaign Group: 30 users
# Control Group:  970 users
# Campaign Retention: 53.3%
# Control Retention:  45.6%
# Retention Lift:     +7.8%
# Campaign Churn Rate: 46.7%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Attack
#    Target: All Users
# ============================================================
#    📧 Open Rate: 77.8% (35/45)
# Campaign Group: 45 users
# Control Group:  955 users
# Campaign Retention: 37.8%
# Control Retention:  46.2%
# Retention Lift:     -8.4%
# Campaign Churn Rate: 62.2%
# Control Churn Rate:  53.8%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Why
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 73.8% (31/42)
# Campaign Group: 41 users
# Control Group:  959 users
# Campaign Retention: 43.9%
# Control Retention:  45.9%
# Retention Lift:     -2.0%
# Campaign Churn Rate: 56.1%
# Control Churn Rate:  54.1%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Support
#    Target: Churned
# ============================================================
#    📧 Open Rate: 88.2% (30/34)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 50.0%
# Control Retention:  45.7%
# Retention Lift:     +4.3%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  54.3%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Data
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 70.0% (28/40)
# Campaign Group: 40 users
# Control Group:  960 users
# Campaign Retention: 50.0%
# Control Retention:  45.6%
# Retention Lift:     +4.4%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Onto
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 80.0% (32/40)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 43.6%
# Control Retention:  45.9%
# Retention Lift:     -2.3%
# Campaign Churn Rate: 56.4%
# Control Churn Rate:  54.1%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Lot
#    Target: New Users
# ============================================================
#    📧 Open Rate: 82.0% (41/50)
# Campaign Group: 50 users
# Control Group:  950 users
# Campaign Retention: 60.0%
# Control Retention:  45.1%
# Retention Lift:     +14.9%
# Campaign Churn Rate: 40.0%
# Control Churn Rate:  54.9%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Job
#    Target: New Users
# ============================================================
#    📧 Open Rate: 80.5% (33/41)
# Campaign Group: 41 users
# Control Group:  959 users
# Campaign Retention: 56.1%
# Control Retention:  45.4%
# Retention Lift:     +10.7%
# Campaign Churn Rate: 43.9%
# Control Churn Rate:  54.6%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Though
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 85.2% (23/27)
# Campaign Group: 26 users
# Control Group:  974 users
# Campaign Retention: 34.6%
# Control Retention:  46.1%
# Retention Lift:     -11.5%
# Campaign Churn Rate: 65.4%
# Control Churn Rate:  53.9%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Compare
#    Target: New Users
# ============================================================
#    📧 Open Rate: 82.1% (23/28)
# Campaign Group: 27 users
# Control Group:  973 users
# Campaign Retention: 51.9%
# Control Retention:  45.6%
# Retention Lift:     +6.2%
# Campaign Churn Rate: 48.1%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Sell
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 89.2% (33/37)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 54.1%
# Control Retention:  45.5%
# Retention Lift:     +8.6%
# Campaign Churn Rate: 45.9%
# Control Churn Rate:  54.5%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Word
#    Target: New Users
# ============================================================
#    📧 Open Rate: 85.3% (29/34)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 35.3%
# Control Retention:  46.2%
# Retention Lift:     -10.9%
# Campaign Churn Rate: 64.7%
# Control Churn Rate:  53.8%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Unit
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 75.0% (27/36)
# Campaign Group: 35 users
# Control Group:  965 users
# Campaign Retention: 48.6%
# Control Retention:  45.7%
# Retention Lift:     +2.9%
# Campaign Churn Rate: 51.4%
# Control Churn Rate:  54.3%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Subject
#    Target: Active
# ============================================================
#    📧 Open Rate: 67.5% (27/40)
# Campaign Group: 40 users
# Control Group:  960 users
# Campaign Retention: 37.5%
# Control Retention:  46.1%
# Retention Lift:     -8.6%
# Campaign Churn Rate: 62.5%
# Control Churn Rate:  53.9%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Admit
#    Target: New Users
# ============================================================
#    📧 Open Rate: 86.1% (31/36)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 27.8%
# Control Retention:  46.5%
# Retention Lift:     -18.7%
# Campaign Churn Rate: 72.2%
# Control Churn Rate:  53.5%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Threat
#    Target: New Users
# ============================================================
#    📧 Open Rate: 78.3% (36/46)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 36.4%
# Control Retention:  46.2%
# Retention Lift:     -9.9%
# Campaign Churn Rate: 63.6%
# Control Churn Rate:  53.8%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Hard
#    Target: Churned
# ============================================================
#    📧 Open Rate: 84.4% (38/45)
# Campaign Group: 43 users
# Control Group:  957 users
# Campaign Retention: 41.9%
# Control Retention:  46.0%
# Retention Lift:     -4.1%
# Campaign Churn Rate: 58.1%
# Control Churn Rate:  54.0%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Off
#    Target: Churned
# ============================================================
#    📧 Open Rate: 92.5% (37/40)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 51.3%
# Control Retention:  45.6%
# Retention Lift:     +5.7%
# Campaign Churn Rate: 48.7%
# Control Churn Rate:  54.4%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Mission
#    Target: Churned
# ============================================================
#    📧 Open Rate: 73.5% (36/49)
# Campaign Group: 49 users
# Control Group:  951 users
# Campaign Retention: 44.9%
# Control Retention:  45.8%
# Retention Lift:     -0.9%
# Campaign Churn Rate: 55.1%
# Control Churn Rate:  54.2%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Dream
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 81.6% (31/38)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 37.8%
# Control Retention:  46.1%
# Retention Lift:     -8.3%
# Campaign Churn Rate: 62.2%
# Control Churn Rate:  53.9%
# Status: Completed
#
# ================================================================================
# CAMPAIGN PERFORMANCE SUMMARY
# ================================================================================
#                 campaign_name target_segment  open_rate  retention_lift    status
#      Onboarding Campaign Mind      All Users       74.4             4.4 Completed
#   Onboarding Campaign Compare      All Users       72.7             2.8 Completed
#       Onboarding Campaign Cut      All Users       75.0             2.9 Completed
#  Onboarding Campaign Cultural      All Users       78.3            -0.4 Completed
#        Upsell Campaign Minute    Medium Risk       90.9            11.5 Completed
#     Upsell Campaign President    Medium Risk       82.0            -1.2 Completed
#         Upsell Campaign Owner    Medium Risk       76.2            -2.0 Completed
#     Retention Campaign Nature      High Risk       84.4            10.8 Completed
#         Upsell Campaign Offer         Active       85.7           -13.9 Completed
#        Retention Campaign For      High Risk       79.5             4.4 Completed
#    Onboarding Campaign Sister      All Users       87.8            10.7 Completed
#    Retention Campaign Science      High Risk       73.0             7.2 Completed
#         Upsell Campaign Place    Medium Risk       77.1             0.0 Completed
#        Upsell Campaign Speech         Active       87.2            -5.1 Completed
#     Upsell Campaign Challenge    Medium Risk       81.2             9.3 Completed
#        Upsell Campaign Return    Medium Risk       69.2            -2.3 Completed
#   Reactivation Campaign Often        Churned       76.5            13.5 Completed
#     Reactivation Campaign Day       Inactive       97.1             1.3 Completed
#    Onboarding Campaign Member      New Users       74.4           -20.3 Completed
# Retention Campaign Successful      High Risk       76.3             5.8 Completed
#     Retention Campaign Travel      High Risk       75.0             1.1 Completed
#    Retention Campaign Instead      High Risk       80.0             4.4 Completed
#       Upsell Campaign Million         Active       84.4             7.6 Completed
#     Retention Campaign Moment        At Risk       82.6            13.5 Completed
# Reactivation Campaign Require       Inactive       73.5            -7.8 Completed
#     Reactivation Campaign But       Inactive       85.0            -6.0 Completed
#         Upsell Campaign World         Active       75.5             1.2 Completed
#     Onboarding Campaign Shake      New Users       82.2           -19.4 Completed
#        Retention Campaign Six      High Risk       72.2             5.8 Completed
# Reactivation Campaign Discuss       Inactive       83.7             3.1 Completed
#        Upsell Campaign Center    Medium Risk       78.1             7.8 Completed
#    Onboarding Campaign Attack      All Users       77.8            -8.4 Completed
#     Reactivation Campaign Why       Inactive       73.8            -2.0 Completed
# Reactivation Campaign Support        Churned       88.2             4.3 Completed
#       Retention Campaign Data        At Risk       70.0             4.4 Completed
#       Retention Campaign Onto      High Risk       80.0            -2.3 Completed
#       Onboarding Campaign Lot      New Users       82.0            14.9 Completed
#       Onboarding Campaign Job      New Users       80.5            10.7 Completed
#  Reactivation Campaign Though       Inactive       85.2           -11.5 Completed
#   Onboarding Campaign Compare      New Users       82.1             6.2 Completed
#       Retention Campaign Sell      High Risk       89.2             8.6 Completed
#      Onboarding Campaign Word      New Users       85.3           -10.9 Completed
#       Retention Campaign Unit      High Risk       75.0             2.9 Completed
#       Upsell Campaign Subject         Active       67.5            -8.6 Completed
#     Onboarding Campaign Admit      New Users       86.1           -18.7 Completed
#    Onboarding Campaign Threat      New Users       78.3            -9.9 Completed
#    Reactivation Campaign Hard        Churned       84.4            -4.1 Completed
#     Reactivation Campaign Off        Churned       92.5             5.7 Completed
# Reactivation Campaign Mission        Churned       73.5            -0.9 Completed
#      Retention Campaign Dream      High Risk       81.6            -8.3 Completed

# %%
print("\n" + "="*80)
print("SAVING CAMPAIGN PERFORMANCE TO DATABASE")
print("="*80)

with SessionLocal() as session:
    deleted = session.query(CampaignPerformance).filter(
        CampaignPerformance.snapshot_date_key == snapshot_date_key
    ).delete()
    session.commit()
    if deleted > 0:
        print(f"Deleted {deleted} existing records for snapshot date {snapshot_date_key}")
        
with SessionLocal() as session:
    for idx, row in campaign_performance_df.iterrows():
        record = CampaignPerformance(
            campaign_key=int(row['campaign_key']),
            snapshot_date_key=int(row['snapshot_date_key']),
            campaign_name=row['campaign_name'],
            target_segment=row['target_segment'],
            launch_date=int(row['launch_date']) if pd.notna(row['launch_date']) else None,
            users_sent=int(row['users_sent']),
            users_opened=int(row['users_opened']),
            open_rate=float(row['open_rate']),
            campaign_retention_rate=float(row['campaign_retention_rate']),
            control_retention_rate=float(row['control_retention_rate']),
            retention_lift=float(row['retention_lift']),
            campaign_churn_rate=float(row['campaign_churn_rate']),      # ← ADDED
            control_churn_rate=float(row['control_churn_rate']),        # ← ADDED
            campaign_size=int(row['campaign_size']),
            control_size=int(row['control_size']),
            status=row['status'],
            created_at=row['created_at']
        )
        session.add(record)
    
    session.commit()

print(f"Saved {len(campaign_performance_df)} campaigns to database")


with SessionLocal() as session:
    count = session.query(CampaignPerformance).filter(
        CampaignPerformance.snapshot_date_key == snapshot_date_key
    ).count()
    
    print(f"Verified: {count} records in database for snapshot {snapshot_date_key}")
# Out:
# ================================================================================
# SAVING CAMPAIGN PERFORMANCE TO DATABASE
# ================================================================================
# Saved 50 campaigns to database
# Verified: 50 records in database for snapshot 20251128
