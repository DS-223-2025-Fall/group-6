# %%
#Imports 
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import text
from Database.database import engine, SessionLocal
from Database.models import (
    FactCampaignInteraction, 
    DimCampaign, 
    FactUserAnalyticsSnapshot,
    CampaignPerformance
)
print("Imports successful")
# Out:
# Imports successful

# %%
snapshot_date_key = int(datetime.now().strftime("%Y%m%d"))

print("\n" + "="*80)
print("LOADING CAMPAIGN DATA")
print("="*80)

with SessionLocal() as session:
    campaigns = session.query(DimCampaign).all()
    campaigns_data = [{
        'campaign_key': c.campaign_key,
        'campaign_name': c.campaign_name,
        'target_risk_segment': c.target_risk_segment,
        'campaign_type': c.campaign_type,
        'start_date_key': c.start_date_key,
        'end_date_key': c.end_date_key
    } for c in campaigns]
    campaigns_df = pd.DataFrame(campaigns_data)
    
    interactions = session.query(FactCampaignInteraction).all()
    interactions_data = [{
        'campaign_key': i.campaign_key,
        'user_key': i.user_key,
        'sent_flag': i.sent_flag,
        'opened_flag': i.opened_flag,
        'clicked_flag': i.clicked_flag,
        'converted_flag': i.converted_flag
    } for i in interactions]
    interactions_df = pd.DataFrame(interactions_data)
    
    users = session.query(FactUserAnalyticsSnapshot).filter(
        FactUserAnalyticsSnapshot.snapshot_date_key == snapshot_date_key
    ).all()
    users_data = [{
        'user_key': u.user_key,
        'segment_label': u.segment_label,
        'engagement_level': u.engagement_level,
        'churn_probability': u.churn_probability
    } for u in users]
    users_df = pd.DataFrame(users_data)

print(f"Loaded {len(campaigns_df)} campaigns")
print(f"Loaded {len(interactions_df):,} interactions")
print(f"Loaded {len(users_df):,} users")

print("\nCampaigns to Analyze:")
print(campaigns_df[['campaign_name', 'target_risk_segment', 'start_date_key']].to_string(index=False))
# Out:
# ================================================================================
# LOADING CAMPAIGN DATA
# ================================================================================
# Loaded 50 campaigns
# Loaded 2,000 interactions
# Loaded 1,000 users
#
# Campaigns to Analyze:
#                     campaign_name target_risk_segment  start_date_key
#         Onboarding Campaign Apply           New Users        20251012
#             Upsell Campaign State              Active        20251127
#        Onboarding Campaign Arrive           All Users        20251015
#               Upsell Campaign Her              Active        20251001
#            Upsell Campaign Design              Active        20250908
#           Retention Campaign Fact           High Risk        20250914
#          Reactivation Campaign Be            Inactive        20251104
#         Retention Campaign Result             At Risk        20250909
#              Upsell Campaign Such         Medium Risk        20251022
#         Onboarding Campaign Party           New Users        20251126
#              Upsell Campaign Hard              Active        20250926
#              Upsell Campaign Soon              Active        20251125
#       Onboarding Campaign Prevent           New Users        20251009
#          Onboarding Campaign Seat           All Users        20250922
#          Retention Campaign Close             At Risk        20250910
#            Retention Campaign Sea             At Risk        20251027
#              Upsell Campaign Poor              Active        20251128
#      Onboarding Campaign Positive           New Users        20251022
#          Onboarding Campaign Kind           All Users        20251129
#            Upsell Campaign Within         Medium Risk        20251010
#               Upsell Campaign Nor              Active        20251010
#     Reactivation Campaign Himself            Inactive        20250924
#     Onboarding Campaign Situation           All Users        20251204
#           Retention Campaign Drug           High Risk        20251011
#          Retention Campaign Their           High Risk        20251130
#        Onboarding Campaign Enough           All Users        20250928
#         Retention Campaign Moment           High Risk        20250913
#              Upsell Campaign Grow              Active        20251103
#         Retention Campaign Weight             At Risk        20251027
#  Reactivation Campaign Technology             Churned        20251022
#         Retention Campaign Little             At Risk        20251119
#     Reactivation Campaign Product            Inactive        20251017
# Reactivation Campaign Participant            Inactive        20251004
#            Upsell Campaign Ground              Active        20250921
#         Onboarding Campaign Other           All Users        20251123
#        Onboarding Campaign Anyone           New Users        20251008
#            Retention Campaign Law             At Risk        20250922
#           Retention Campaign Save             At Risk        20250929
#        Reactivation Campaign Bill            Inactive        20251201
#        Reactivation Campaign Item            Inactive        20251022
#         Retention Campaign Create             At Risk        20251030
#           Onboarding Campaign Ten           All Users        20251009
#      Onboarding Campaign Position           New Users        20251015
#          Onboarding Campaign Unit           All Users        20251005
#        Reactivation Campaign Face             Churned        20251204
#               Upsell Campaign Yes         Medium Risk        20251023
#         Onboarding Campaign About           All Users        20250924
#          Retention Campaign Cause           High Risk        20250926
#        Onboarding Campaign Appear           New Users        20250922
#           Onboarding Campaign Set           All Users        20251108

# %%
print("\n" + "="*80)
print("CALCULATING PER-CAMPAIGN PERFORMANCE")
print("="*80)

campaign_performance_list = []

for idx, campaign in campaigns_df.iterrows():
    campaign_key = campaign['campaign_key']
    campaign_name = campaign['campaign_name']
    target_segment = campaign['target_risk_segment']
    
    print(f"\n{'='*60}")
    print(f"Campaign: {campaign_name}")
    print(f"   Target: {target_segment}")
    print(f"{'='*60}")
    
    campaign_interactions = interactions_df[interactions_df['campaign_key'] == campaign_key]
    
    if len(campaign_interactions) == 0:
        print(f"No interactions found - skipping")
        continue
    
    # Open rate
    users_sent = int(campaign_interactions['sent_flag'].sum())
    users_opened = int(campaign_interactions['opened_flag'].sum())
    open_rate = (users_opened / users_sent * 100) if users_sent > 0 else 0
    
    print(f"   📧 Open Rate: {open_rate:.1f}% ({users_opened}/{users_sent})")
    
    # Retention lift
    campaign_user_keys = campaign_interactions['user_key'].unique()
    campaign_users = users_df[users_df['user_key'].isin(campaign_user_keys)].copy()
    
    segment_mapping = {
        'At-Risk': ['At-Risk Premium', 'Declining Premium', 'Need Attention'],
        'Dormant': ['Dormant Premium', 'Recently Churned'],
        'Medium': ['Medium Engaged', 'Potential Loyalists'],
        'Highly Engaged': ['Champions', 'Loyal Customers', 'Highly Engaged'],
        'All': None  
    }
    
    if target_segment and target_segment in segment_mapping:
        target_segments = segment_mapping[target_segment]
        
        if target_segments:
            # Control: same segment type, didn't receive campaign
            control_users = users_df[
                (~users_df['user_key'].isin(campaign_user_keys)) &
                (users_df['segment_label'].isin(target_segments))
            ].copy()
        else:
            # Target = All
            control_users = users_df[~users_df['user_key'].isin(campaign_user_keys)].copy()
    else:
        control_users = users_df[~users_df['user_key'].isin(campaign_user_keys)].copy()
    
    print(f"Campaign Group: {len(campaign_users):,} users")
    print(f"Control Group:  {len(control_users):,} users")
    
    if len(control_users) == 0:
        print(f"WARNING: No control users found for segment '{target_segment}'")
        print(f"Using all non-campaign users as control")
        control_users = users_df[~users_df['user_key'].isin(campaign_user_keys)].copy()
        print(f"Control Group (fallback): {len(control_users):,} users")
    
    campaign_users['is_retained'] = (
        ~campaign_users['segment_label'].isin(['Recently Churned', 'Dormant Premium']) &
        (campaign_users['churn_probability'] < 0.5)
    ).astype(int)
    
    control_users['is_retained'] = (
        ~control_users['segment_label'].isin(['Recently Churned', 'Dormant Premium']) &
        (control_users['churn_probability'] < 0.5)
    ).astype(int)
    
    campaign_retention = (campaign_users['is_retained'].mean() * 100) if len(campaign_users) > 0 else 0
    control_retention = (control_users['is_retained'].mean() * 100) if len(control_users) > 0 else 0
    retention_lift = campaign_retention - control_retention
    
    print(f"Campaign Retention: {campaign_retention:.1f}%")
    print(f"Control Retention:  {control_retention:.1f}%")
    print(f"Retention Lift:     {retention_lift:+.1f}%")
    
    # Churn Rate
    campaign_churn_rate = 100 - campaign_retention
    control_churn_rate = 100 - control_retention
    
    print(f"Campaign Churn Rate: {campaign_churn_rate:.1f}%")
    print(f"Control Churn Rate:  {control_churn_rate:.1f}%")
    
    # Status
    current_date = int(datetime.now().strftime("%Y%m%d"))
    
    if campaign['end_date_key'] and current_date > campaign['end_date_key']:
        status = "Completed"
    elif campaign['start_date_key'] and current_date >= campaign['start_date_key']:
        status = "Active"
    else:
        status = "Scheduled"
    
    print(f"Status: {status}")
    
    # Results
    campaign_performance_list.append({
        'campaign_key': campaign_key,
        'snapshot_date_key': snapshot_date_key,
        'campaign_name': campaign_name,
        'target_segment': target_segment,
        'launch_date': campaign['start_date_key'],
        'users_sent': users_sent,
        'users_opened': users_opened,
        'open_rate': round(open_rate, 1),
        'campaign_retention_rate': round(campaign_retention, 1),
        'control_retention_rate': round(control_retention, 1),
        'retention_lift': round(retention_lift, 1),
        'campaign_churn_rate': round(campaign_churn_rate, 1),      # ← NEW
        'control_churn_rate': round(control_churn_rate, 1),        # ← NEW
        'campaign_size': len(campaign_users),
        'control_size': len(control_users),
        'status': status,
        'created_at': datetime.now()
    })

campaign_performance_df = pd.DataFrame(campaign_performance_list)

print("\n" + "="*80)
print("CAMPAIGN PERFORMANCE SUMMARY")
print("="*80)
print(campaign_performance_df[[
    'campaign_name', 
    'target_segment',
    'open_rate', 
    'retention_lift',
    'status'
]].to_string(index=False))
# Out:
# ================================================================================
# CALCULATING PER-CAMPAIGN PERFORMANCE
# ================================================================================
#
# ============================================================
# Campaign: Onboarding Campaign Apply
#    Target: New Users
# ============================================================
#    📧 Open Rate: 80.4% (37/46)
# Campaign Group: 43 users
# Control Group:  957 users
# Campaign Retention: 53.5%
# Control Retention:  40.2%
# Retention Lift:     +13.3%
# Campaign Churn Rate: 46.5%
# Control Churn Rate:  59.8%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign State
#    Target: Active
# ============================================================
#    📧 Open Rate: 80.5% (33/41)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 48.7%
# Control Retention:  40.5%
# Retention Lift:     +8.2%
# Campaign Churn Rate: 51.3%
# Control Churn Rate:  59.5%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Arrive
#    Target: All Users
# ============================================================
#    📧 Open Rate: 82.5% (33/40)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 35.9%
# Control Retention:  41.0%
# Retention Lift:     -5.1%
# Campaign Churn Rate: 64.1%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Her
#    Target: Active
# ============================================================
#    📧 Open Rate: 71.4% (25/35)
# Campaign Group: 35 users
# Control Group:  965 users
# Campaign Retention: 42.9%
# Control Retention:  40.7%
# Retention Lift:     +2.1%
# Campaign Churn Rate: 57.1%
# Control Churn Rate:  59.3%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Design
#    Target: Active
# ============================================================
#    📧 Open Rate: 82.9% (34/41)
# Campaign Group: 40 users
# Control Group:  960 users
# Campaign Retention: 35.0%
# Control Retention:  41.0%
# Retention Lift:     -6.0%
# Campaign Churn Rate: 65.0%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Fact
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 79.5% (31/39)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 41.0%
# Control Retention:  40.8%
# Retention Lift:     +0.2%
# Campaign Churn Rate: 59.0%
# Control Churn Rate:  59.2%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Be
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 70.3% (26/37)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 47.2%
# Control Retention:  40.6%
# Retention Lift:     +6.7%
# Campaign Churn Rate: 52.8%
# Control Churn Rate:  59.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Result
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 71.8% (28/39)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 35.1%
# Control Retention:  41.0%
# Retention Lift:     -5.9%
# Campaign Churn Rate: 64.9%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Such
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 86.1% (31/36)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 44.1%
# Control Retention:  40.7%
# Retention Lift:     +3.4%
# Campaign Churn Rate: 55.9%
# Control Churn Rate:  59.3%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Party
#    Target: New Users
# ============================================================
#    📧 Open Rate: 80.4% (37/46)
# Campaign Group: 46 users
# Control Group:  954 users
# Campaign Retention: 41.3%
# Control Retention:  40.8%
# Retention Lift:     +0.5%
# Campaign Churn Rate: 58.7%
# Control Churn Rate:  59.2%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Hard
#    Target: Active
# ============================================================
#    📧 Open Rate: 85.4% (35/41)
# Campaign Group: 40 users
# Control Group:  960 users
# Campaign Retention: 50.0%
# Control Retention:  40.4%
# Retention Lift:     +9.6%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  59.6%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Soon
#    Target: Active
# ============================================================
#    📧 Open Rate: 74.5% (35/47)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 40.9%
# Control Retention:  40.8%
# Retention Lift:     +0.1%
# Campaign Churn Rate: 59.1%
# Control Churn Rate:  59.2%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Prevent
#    Target: New Users
# ============================================================
#    📧 Open Rate: 85.7% (30/35)
# Campaign Group: 35 users
# Control Group:  965 users
# Campaign Retention: 34.3%
# Control Retention:  41.0%
# Retention Lift:     -6.8%
# Campaign Churn Rate: 65.7%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Seat
#    Target: All Users
# ============================================================
#    📧 Open Rate: 73.8% (31/42)
# Campaign Group: 42 users
# Control Group:  958 users
# Campaign Retention: 52.4%
# Control Retention:  40.3%
# Retention Lift:     +12.1%
# Campaign Churn Rate: 47.6%
# Control Churn Rate:  59.7%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Close
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 91.4% (32/35)
# Campaign Group: 35 users
# Control Group:  965 users
# Campaign Retention: 51.4%
# Control Retention:  40.4%
# Retention Lift:     +11.0%
# Campaign Churn Rate: 48.6%
# Control Churn Rate:  59.6%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Sea
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 79.6% (43/54)
# Campaign Group: 51 users
# Control Group:  949 users
# Campaign Retention: 37.3%
# Control Retention:  41.0%
# Retention Lift:     -3.7%
# Campaign Churn Rate: 62.7%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Poor
#    Target: Active
# ============================================================
#    📧 Open Rate: 76.9% (30/39)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 62.2%
# Control Retention:  40.0%
# Retention Lift:     +22.2%
# Campaign Churn Rate: 37.8%
# Control Churn Rate:  60.0%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Positive
#    Target: New Users
# ============================================================
#    📧 Open Rate: 85.7% (30/35)
# Campaign Group: 32 users
# Control Group:  968 users
# Campaign Retention: 28.1%
# Control Retention:  41.2%
# Retention Lift:     -13.1%
# Campaign Churn Rate: 71.9%
# Control Churn Rate:  58.8%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Kind
#    Target: All Users
# ============================================================
#    📧 Open Rate: 86.1% (31/36)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 25.0%
# Control Retention:  41.4%
# Retention Lift:     -16.4%
# Campaign Churn Rate: 75.0%
# Control Churn Rate:  58.6%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Within
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 74.2% (23/31)
# Campaign Group: 30 users
# Control Group:  970 users
# Campaign Retention: 50.0%
# Control Retention:  40.5%
# Retention Lift:     +9.5%
# Campaign Churn Rate: 50.0%
# Control Churn Rate:  59.5%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Nor
#    Target: Active
# ============================================================
#    📧 Open Rate: 80.0% (32/40)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 41.0%
# Control Retention:  40.8%
# Retention Lift:     +0.2%
# Campaign Churn Rate: 59.0%
# Control Churn Rate:  59.2%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Himself
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 83.3% (35/42)
# Campaign Group: 41 users
# Control Group:  959 users
# Campaign Retention: 43.9%
# Control Retention:  40.7%
# Retention Lift:     +3.2%
# Campaign Churn Rate: 56.1%
# Control Churn Rate:  59.3%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Situation
#    Target: All Users
# ============================================================
#    📧 Open Rate: 65.6% (21/32)
# Campaign Group: 32 users
# Control Group:  968 users
# Campaign Retention: 40.6%
# Control Retention:  40.8%
# Retention Lift:     -0.2%
# Campaign Churn Rate: 59.4%
# Control Churn Rate:  59.2%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Drug
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 81.1% (30/37)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 30.6%
# Control Retention:  41.2%
# Retention Lift:     -10.6%
# Campaign Churn Rate: 69.4%
# Control Churn Rate:  58.8%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Their
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 72.2% (26/36)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 55.6%
# Control Retention:  40.2%
# Retention Lift:     +15.3%
# Campaign Churn Rate: 44.4%
# Control Churn Rate:  59.8%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Enough
#    Target: All Users
# ============================================================
#    📧 Open Rate: 72.2% (26/36)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 33.3%
# Control Retention:  41.1%
# Retention Lift:     -7.7%
# Campaign Churn Rate: 66.7%
# Control Churn Rate:  58.9%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Moment
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 81.4% (35/43)
# Campaign Group: 43 users
# Control Group:  957 users
# Campaign Retention: 39.5%
# Control Retention:  40.9%
# Retention Lift:     -1.3%
# Campaign Churn Rate: 60.5%
# Control Churn Rate:  59.1%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Grow
#    Target: Active
# ============================================================
#    📧 Open Rate: 87.5% (28/32)
# Campaign Group: 32 users
# Control Group:  968 users
# Campaign Retention: 53.1%
# Control Retention:  40.4%
# Retention Lift:     +12.7%
# Campaign Churn Rate: 46.9%
# Control Churn Rate:  59.6%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Weight
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 87.5% (35/40)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 35.9%
# Control Retention:  41.0%
# Retention Lift:     -5.1%
# Campaign Churn Rate: 64.1%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Technology
#    Target: Churned
# ============================================================
#    📧 Open Rate: 77.3% (34/44)
# Campaign Group: 42 users
# Control Group:  958 users
# Campaign Retention: 35.7%
# Control Retention:  41.0%
# Retention Lift:     -5.3%
# Campaign Churn Rate: 64.3%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Little
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 78.9% (30/38)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 29.7%
# Control Retention:  41.2%
# Retention Lift:     -11.5%
# Campaign Churn Rate: 70.3%
# Control Churn Rate:  58.8%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Product
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 84.8% (28/33)
# Campaign Group: 33 users
# Control Group:  967 users
# Campaign Retention: 48.5%
# Control Retention:  40.5%
# Retention Lift:     +7.9%
# Campaign Churn Rate: 51.5%
# Control Churn Rate:  59.5%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Participant
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 89.2% (33/37)
# Campaign Group: 37 users
# Control Group:  963 users
# Campaign Retention: 43.2%
# Control Retention:  40.7%
# Retention Lift:     +2.5%
# Campaign Churn Rate: 56.8%
# Control Churn Rate:  59.3%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Ground
#    Target: Active
# ============================================================
#    📧 Open Rate: 66.7% (24/36)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 38.9%
# Control Retention:  40.9%
# Retention Lift:     -2.0%
# Campaign Churn Rate: 61.1%
# Control Churn Rate:  59.1%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Other
#    Target: All Users
# ============================================================
#    📧 Open Rate: 87.5% (42/48)
# Campaign Group: 48 users
# Control Group:  952 users
# Campaign Retention: 39.6%
# Control Retention:  40.9%
# Retention Lift:     -1.3%
# Campaign Churn Rate: 60.4%
# Control Churn Rate:  59.1%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Anyone
#    Target: New Users
# ============================================================
#    📧 Open Rate: 79.5% (31/39)
# Campaign Group: 39 users
# Control Group:  961 users
# Campaign Retention: 30.8%
# Control Retention:  41.2%
# Retention Lift:     -10.4%
# Campaign Churn Rate: 69.2%
# Control Churn Rate:  58.8%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Law
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 75.8% (25/33)
# Campaign Group: 33 users
# Control Group:  967 users
# Campaign Retention: 45.5%
# Control Retention:  40.6%
# Retention Lift:     +4.8%
# Campaign Churn Rate: 54.5%
# Control Churn Rate:  59.4%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Save
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 80.0% (36/45)
# Campaign Group: 44 users
# Control Group:  956 users
# Campaign Retention: 36.4%
# Control Retention:  41.0%
# Retention Lift:     -4.6%
# Campaign Churn Rate: 63.6%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Bill
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 81.4% (35/43)
# Campaign Group: 43 users
# Control Group:  957 users
# Campaign Retention: 37.2%
# Control Retention:  41.0%
# Retention Lift:     -3.8%
# Campaign Churn Rate: 62.8%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Item
#    Target: Inactive
# ============================================================
#    📧 Open Rate: 79.2% (38/48)
# Campaign Group: 46 users
# Control Group:  954 users
# Campaign Retention: 43.5%
# Control Retention:  40.7%
# Retention Lift:     +2.8%
# Campaign Churn Rate: 56.5%
# Control Churn Rate:  59.3%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Create
#    Target: At Risk
# ============================================================
#    📧 Open Rate: 72.1% (31/43)
# Campaign Group: 42 users
# Control Group:  958 users
# Campaign Retention: 35.7%
# Control Retention:  41.0%
# Retention Lift:     -5.3%
# Campaign Churn Rate: 64.3%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Ten
#    Target: All Users
# ============================================================
#    📧 Open Rate: 89.6% (43/48)
# Campaign Group: 46 users
# Control Group:  954 users
# Campaign Retention: 37.0%
# Control Retention:  41.0%
# Retention Lift:     -4.0%
# Campaign Churn Rate: 63.0%
# Control Churn Rate:  59.0%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Position
#    Target: New Users
# ============================================================
#    📧 Open Rate: 81.0% (34/42)
# Campaign Group: 42 users
# Control Group:  958 users
# Campaign Retention: 38.1%
# Control Retention:  40.9%
# Retention Lift:     -2.8%
# Campaign Churn Rate: 61.9%
# Control Churn Rate:  59.1%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Unit
#    Target: All Users
# ============================================================
#    📧 Open Rate: 76.3% (29/38)
# Campaign Group: 38 users
# Control Group:  962 users
# Campaign Retention: 28.9%
# Control Retention:  41.3%
# Retention Lift:     -12.3%
# Campaign Churn Rate: 71.1%
# Control Churn Rate:  58.7%
# Status: Completed
#
# ============================================================
# Campaign: Reactivation Campaign Face
#    Target: Churned
# ============================================================
#    📧 Open Rate: 84.4% (27/32)
# Campaign Group: 32 users
# Control Group:  968 users
# Campaign Retention: 31.2%
# Control Retention:  41.1%
# Retention Lift:     -9.9%
# Campaign Churn Rate: 68.8%
# Control Churn Rate:  58.9%
# Status: Completed
#
# ============================================================
# Campaign: Upsell Campaign Yes
#    Target: Medium Risk
# ============================================================
#    📧 Open Rate: 74.3% (26/35)
# Campaign Group: 34 users
# Control Group:  966 users
# Campaign Retention: 38.2%
# Control Retention:  40.9%
# Retention Lift:     -2.7%
# Campaign Churn Rate: 61.8%
# Control Churn Rate:  59.1%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign About
#    Target: All Users
# ============================================================
#    📧 Open Rate: 87.2% (41/47)
# Campaign Group: 47 users
# Control Group:  953 users
# Campaign Retention: 48.9%
# Control Retention:  40.4%
# Retention Lift:     +8.5%
# Campaign Churn Rate: 51.1%
# Control Churn Rate:  59.6%
# Status: Completed
#
# ============================================================
# Campaign: Retention Campaign Cause
#    Target: High Risk
# ============================================================
#    📧 Open Rate: 82.6% (38/46)
# Campaign Group: 45 users
# Control Group:  955 users
# Campaign Retention: 33.3%
# Control Retention:  41.2%
# Retention Lift:     -7.8%
# Campaign Churn Rate: 66.7%
# Control Churn Rate:  58.8%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Appear
#    Target: New Users
# ============================================================
#    📧 Open Rate: 79.2% (42/53)
# Campaign Group: 50 users
# Control Group:  950 users
# Campaign Retention: 42.0%
# Control Retention:  40.7%
# Retention Lift:     +1.3%
# Campaign Churn Rate: 58.0%
# Control Churn Rate:  59.3%
# Status: Completed
#
# ============================================================
# Campaign: Onboarding Campaign Set
#    Target: All Users
# ============================================================
#    📧 Open Rate: 84.6% (33/39)
# Campaign Group: 36 users
# Control Group:  964 users
# Campaign Retention: 55.6%
# Control Retention:  40.2%
# Retention Lift:     +15.3%
# Campaign Churn Rate: 44.4%
# Control Churn Rate:  59.8%
# Status: Completed
#
# ================================================================================
# CAMPAIGN PERFORMANCE SUMMARY
# ================================================================================
#                     campaign_name target_segment  open_rate  retention_lift    status
#         Onboarding Campaign Apply      New Users       80.4            13.3 Completed
#             Upsell Campaign State         Active       80.5             8.2 Completed
#        Onboarding Campaign Arrive      All Users       82.5            -5.1 Completed
#               Upsell Campaign Her         Active       71.4             2.1 Completed
#            Upsell Campaign Design         Active       82.9            -6.0 Completed
#           Retention Campaign Fact      High Risk       79.5             0.2 Completed
#          Reactivation Campaign Be       Inactive       70.3             6.7 Completed
#         Retention Campaign Result        At Risk       71.8            -5.9 Completed
#              Upsell Campaign Such    Medium Risk       86.1             3.4 Completed
#         Onboarding Campaign Party      New Users       80.4             0.5 Completed
#              Upsell Campaign Hard         Active       85.4             9.6 Completed
#              Upsell Campaign Soon         Active       74.5             0.1 Completed
#       Onboarding Campaign Prevent      New Users       85.7            -6.8 Completed
#          Onboarding Campaign Seat      All Users       73.8            12.1 Completed
#          Retention Campaign Close        At Risk       91.4            11.0 Completed
#            Retention Campaign Sea        At Risk       79.6            -3.7 Completed
#              Upsell Campaign Poor         Active       76.9            22.2 Completed
#      Onboarding Campaign Positive      New Users       85.7           -13.1 Completed
#          Onboarding Campaign Kind      All Users       86.1           -16.4 Completed
#            Upsell Campaign Within    Medium Risk       74.2             9.5 Completed
#               Upsell Campaign Nor         Active       80.0             0.2 Completed
#     Reactivation Campaign Himself       Inactive       83.3             3.2 Completed
#     Onboarding Campaign Situation      All Users       65.6            -0.2 Completed
#           Retention Campaign Drug      High Risk       81.1           -10.6 Completed
#          Retention Campaign Their      High Risk       72.2            15.3 Completed
#        Onboarding Campaign Enough      All Users       72.2            -7.7 Completed
#         Retention Campaign Moment      High Risk       81.4            -1.3 Completed
#              Upsell Campaign Grow         Active       87.5            12.7 Completed
#         Retention Campaign Weight        At Risk       87.5            -5.1 Completed
#  Reactivation Campaign Technology        Churned       77.3            -5.3 Completed
#         Retention Campaign Little        At Risk       78.9           -11.5 Completed
#     Reactivation Campaign Product       Inactive       84.8             7.9 Completed
# Reactivation Campaign Participant       Inactive       89.2             2.5 Completed
#            Upsell Campaign Ground         Active       66.7            -2.0 Completed
#         Onboarding Campaign Other      All Users       87.5            -1.3 Completed
#        Onboarding Campaign Anyone      New Users       79.5           -10.4 Completed
#            Retention Campaign Law        At Risk       75.8             4.8 Completed
#           Retention Campaign Save        At Risk       80.0            -4.6 Completed
#        Reactivation Campaign Bill       Inactive       81.4            -3.8 Completed
#        Reactivation Campaign Item       Inactive       79.2             2.8 Completed
#         Retention Campaign Create        At Risk       72.1            -5.3 Completed
#           Onboarding Campaign Ten      All Users       89.6            -4.0 Completed
#      Onboarding Campaign Position      New Users       81.0            -2.8 Completed
#          Onboarding Campaign Unit      All Users       76.3           -12.3 Completed
#        Reactivation Campaign Face        Churned       84.4            -9.9 Completed
#               Upsell Campaign Yes    Medium Risk       74.3            -2.7 Completed
#         Onboarding Campaign About      All Users       87.2             8.5 Completed
#          Retention Campaign Cause      High Risk       82.6            -7.8 Completed
#        Onboarding Campaign Appear      New Users       79.2             1.3 Completed
#           Onboarding Campaign Set      All Users       84.6            15.3 Completed

# %%
print("\n" + "="*80)
print("SAVING CAMPAIGN PERFORMANCE TO DATABASE")
print("="*80)

with SessionLocal() as session:
    deleted = session.query(CampaignPerformance).filter(
        CampaignPerformance.snapshot_date_key == snapshot_date_key
    ).delete()
    session.commit()
    if deleted > 0:
        print(f"Deleted {deleted} existing records for snapshot date {snapshot_date_key}")
        
with SessionLocal() as session:
    for idx, row in campaign_performance_df.iterrows():
        record = CampaignPerformance(
            campaign_key=int(row['campaign_key']),
            snapshot_date_key=int(row['snapshot_date_key']),
            campaign_name=row['campaign_name'],
            target_segment=row['target_segment'],
            launch_date=int(row['launch_date']) if pd.notna(row['launch_date']) else None,
            users_sent=int(row['users_sent']),
            users_opened=int(row['users_opened']),
            open_rate=float(row['open_rate']),
            campaign_retention_rate=float(row['campaign_retention_rate']),
            control_retention_rate=float(row['control_retention_rate']),
            retention_lift=float(row['retention_lift']),
            campaign_churn_rate=float(row['campaign_churn_rate']),      # ← ADDED
            control_churn_rate=float(row['control_churn_rate']),        # ← ADDED
            campaign_size=int(row['campaign_size']),
            control_size=int(row['control_size']),
            status=row['status'],
            created_at=row['created_at']
        )
        session.add(record)
    
    session.commit()

print(f"Saved {len(campaign_performance_df)} campaigns to database")


with SessionLocal() as session:
    count = session.query(CampaignPerformance).filter(
        CampaignPerformance.snapshot_date_key == snapshot_date_key
    ).count()
    
    print(f"Verified: {count} records in database for snapshot {snapshot_date_key}")
# Out:
# ================================================================================
# SAVING CAMPAIGN PERFORMANCE TO DATABASE
# ================================================================================
# Saved 50 campaigns to database
# Verified: 50 records in database for snapshot 20251206
